# %% [markdown]
# # **BankIntel AI Chatbot Model creation**

# %%
import pandas as pd

# %% [markdown]
# ### **Data Loading**

# %%
train_df = pd.read_csv("dataset/train.csv")
test_df = pd.read_csv("dataset/test.csv")
dev_df = pd.read_csv("dataset/dev.csv")

# %%
print(train_df.shape)
train_df.sample(5)
# Out:
# (10003, 3)
#                                                    text  label                      label_text
# 8920  I see in the app some cash was withdrawn, but ...     20  cash_withdrawal_not_recognised
# 3203  I think my top up may have been reverted, what...     61                 top_up_reverted
# 2246                       Are there any top-up limits?     60                   top_up_limits
# 2962          What currency is acceptable for a top up?     54  supported_cards_and_currencies
# 7364                   How do I get money from friends?     50                 receiving_money

# %%
print(test_df.shape)
test_df.sample(5)
# Out:
# (3080, 3)
#                                                    text  label                      label_text
# 1339      Will my friend be able to top off my account?     62              topping_up_by_card
# 2722  I just lost my wallet and I see that they are ...     20  cash_withdrawal_not_recognised
# 2001      I want information about the source of funds.     70          verify_source_of_funds
# 2495                       Where can you deliver cards?     43             order_physical_card
# 2889      Why was I charged a fee for withdrawing cash?     19          cash_withdrawal_charge

# %%
print(dev_df.shape)
dev_df.sample(5)
# Out:
# (3080, 3)
#                                                    text  label                        label_text
# 406                       How are currencies exchanged?     33                  exchange_via_app
# 121   I made a currency exchange and think I was cha...     17  card_payment_wrong_exchange_rate
# 587                  The contactless I have won't work.     23           contactless_not_working
# 1254                                what is my card PIN     38                 get_physical_card
# 2950    The expiration date of my card is approaching .      9              card_about_to_expire
